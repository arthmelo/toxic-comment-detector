# %%
import pandas as pd
import numpy as np
import spacy
import re
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/comentarios_toxicos_ptBR.csv')
df.dropna(subset=['text', 'toxic'], inplace=True)
df.head()
# Out:
#    Unnamed: 0                                               text  \
# 0       12451                        brocolis é muito boooom pqp
# 1        4080                                  to correndo disso
# 2        5195  presidente da oab sofre amea莽as de morte e aci...
# 3       13375  @user @user aí desanima pq para de vir teus ch...
# 4        4130  ser feio e beta é um bosta, puta que me pariu....
#
#                                            text_norm  toxic
# 0                           brócolis boom puta pariu      0
# 1                                  to correndo disso      0
# 2  presidente aba sofre ame-a morte aciona polega...      0
# 3  aí desanima porque vir champ chato pra caralho...      1
# 4  feio beta bosta puta pariu lá vou comprar ócul...      1

# %%
nlp = spacy.load("pt_core_news_sm")

def preProcessar(texto):
    texto = str(texto).lower()
    texto = re.sub(r'[^a-záéíóúâêôãõüç\s]', '', texto)
    doc = nlp(texto)
    return " ".join([token.text for token in doc if not token.is_stop and token.text.strip()])

print("Processando textos (isso pode demorar alguns minutos)...")
if 'text_norm' in df.columns:
    df.dropna(subset=['text_norm'], inplace=True)
    df['text_normalized_str'] = df['text_norm']
else:
    df['text_normalized_str'] = df['text'].apply(preProcessar)

df[['text', 'text_normalized_str', 'toxic']].head()
# Out:
# Processando textos (isso pode demorar alguns minutos)...
#                                                 text  \
# 0                        brocolis é muito boooom pqp
# 1                                  to correndo disso
# 2  presidente da oab sofre amea莽as de morte e aci...
# 3  @user @user aí desanima pq para de vir teus ch...
# 4  ser feio e beta é um bosta, puta que me pariu....
#
#                                  text_normalized_str  toxic
# 0                           brócolis boom puta pariu      0
# 1                                  to correndo disso      0
# 2  presidente aba sofre ame-a morte aciona polega...      0
# 3  aí desanima porque vir champ chato pra caralho...      1
# 4  feio beta bosta puta pariu lá vou comprar ócul...      1

# %%
X = df['text_normalized_str']
y = df['toxic']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42, stratify=y
)
print("Treino:", len(X_train))
print("Teste:", len(X_test))
# Out:
# Treino: 23894
# Teste: 5974

# %%
tfidf = TfidfVectorizer(max_features=10000)
X_train_vec = tfidf.fit_transform(X_train)
X_test_vec = tfidf.transform(X_test)

# %%
model = MultinomialNB()
model.fit(X_train_vec, y_train)
print("Modelo MultinomialNB treinado com sucesso!")
# Out:
# Modelo MultinomialNB treinado com sucesso!

# %%
y_pred = model.predict(X_test_vec)

print("Relatório de Classificação:")
print(classification_report(y_test, y_pred, target_names=['Não Tóxico', 'Tóxico']))
# Out:
# Relatório de Classificação:
#               precision    recall  f1-score   support
#
#   Não Tóxico       0.72      0.82      0.77      3272
#       Tóxico       0.74      0.62      0.67      2702
#
#     accuracy                           0.73      5974
#    macro avg       0.73      0.72      0.72      5974
# weighted avg       0.73      0.73      0.72      5974

# %%
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Não Tóxico', 'Tóxico'])
disp.plot(cmap=plt.cm.Blues)
plt.title('Matriz de Confusão - Multinomial Naive Bayes')
plt.show()

# %%
def previsao(text):
    text_processed = preProcessar(text)
    vec = tfidf.transform([text_processed])
    prob = model.predict_proba(vec)[0][1]
    pred = model.predict(vec)[0]
    return pred, prob

# %%
testes = [
    "Você é um idiota!",
    "Eu gostei muito desse vídeo.",
    "Que coisa maravilhosa!",
    "Esse cara é muito burro.",
    "Não concordo com você.",
    "Vai para o inferno."
]

for texto in testes:
    resultado, probabilidade = previsao(texto)
    classe = "Tóxico" if resultado == 1 else "Não Tóxico"
    print(f"Texto: '{texto}' | Previsão: {classe} | Prob(Tóxico): {probabilidade:.2%}")
# Out:
# Texto: 'Você é um idiota!' | Previsão: Tóxico | Prob(Tóxico): 64.36%
# Texto: 'Eu gostei muito desse vídeo.' | Previsão: Não Tóxico | Prob(Tóxico): 30.10%
# Texto: 'Que coisa maravilhosa!' | Previsão: Não Tóxico | Prob(Tóxico): 21.83%
# Texto: 'Esse cara é muito burro.' | Previsão: Tóxico | Prob(Tóxico): 74.92%
# Texto: 'Não concordo com você.' | Previsão: Não Tóxico | Prob(Tóxico): 22.27%
# Texto: 'Vai para o inferno.' | Previsão: Tóxico | Prob(Tóxico): 63.21%
